# %% [markdown]
# https://www.gresearch.co.uk/blog/article/faster-string-processing-in-pandas/
#
# https://gist.github.com/anshoomehra/ead8925ea291e233a5aa2dcaa2dc61b2

# %%
import pandas as pd
import cython
import os
import re
import json
from bs4 import BeautifulSoup
from multiprocessing import Pool

# %%
os.chdir('/mnt/d/workspace/8-2/Financial-Statements-Text-Analysis/')

# %%
# params
with open('config.json', 'r') as f:
    c = json.load(f)
input_dir = os.path.join(c['DATA_DIR'], '10k_raw')
destination_dir = os.path.join(c['DATA_DIR'], '10k_clean')

# %%
metadata = pd.read_csv(os.path.join(c['DATA_DIR'], 'metadata.csv'))
metadata_legacy = pd.read_csv(os.path.join(c['DATA_DIR'], 'metadata_2017.csv'))

# only download the data from russell 3000 today
metadata = metadata_legacy[metadata_legacy['TICKER'].isin(metadata['ticker'])]

# %%
def parse_filing(text):
    regex_10k = re.search(r"(?s)(?m)<TYPE>10-K.*?(</TEXT>)", text)
    regex_items = re.compile(r"(> +Item|>Item|^Item|ITEM)((\s|&#160;|&nbsp;)(1A|1B|7A|7|8))")
    
    try: 
        extracted_text = regex_10k.group(0)
    except:
        print('❌ No 10-K match for file')
    
    item_matches = regex_items.finditer(extracted_text)
    matches_df = pd.DataFrame([(x.group(), x.start()) for x in item_matches])
    matches_df.columns = ['item', 'start']
    matches_df['item'] = matches_df['item'].str.lower().replace('>|\.| |&#160;|&nbsp|;', '', regex=True)
    matches_df = matches_df.sort_values('start').drop_duplicates(subset=['item'], keep='last')
    matches_df['end'] = matches_df['start'].shift(-1).fillna(0).astype(int)
    matches_df = matches_df[matches_df['item'].isin(['item1a', 'item1b', 'item7', 'item7a'])]
    if len(matches_df) != 4:
        print('❌ Only {sections} sections found for file'.format(sections=len(matches_df)))
    matches_df['text'] = matches_df\
        .apply(lambda row: BeautifulSoup(extracted_text[row['start']:row['end']], 'lxml').get_text('\n\n'), axis=1)
    
    return matches_df

def process_filing(i):
    ticker = metadata.iloc[i]['TICKER']
    leaf = metadata.iloc[i]['EDGAR_LINK'].split("/")[-1]
    
    input_file_name = os.path.join(input_dir,
                             ticker, leaf)
    with open(input_file_name, 'r', encoding='utf-8') as f:
        file = f.read()
    
    try:
        clean_df = parse_filing(file)
    
        destination_file = os.path.join(destination_dir, ticker, leaf)

        destination_subdir = os.path.dirname(destination_file)

        if not os.path.isdir(destination_subdir):
            os.makedirs(destination_subdir)

        clean_df.to_csv(destination_file)
        print('Successfully parsed for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        return clean_df
        
    except Exception as e:
        print('Failed parse for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        print(e)
        print('\n')

# %%
# %load_ext line_profiler

# %%
# %lprun -f parse_filing process_filing(10)
# Out:
# UsageError: Cell magic `%%lprun` not found (But line magic `%lprun` exists, did you mean that instead?).

# %% [raw]
# Timer unit: 1e-09 s
#
# Total time: 1.01158 s
# File: /tmp/ipykernel_10528/340092788.py
# Function: parse_filing at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def parse_filing(text):
#      2         1  111199000.0 111199000.0   11.0      regex_10k = re.search(r"(?s)(?m)<TYPE>10-K.*?(</TEXT>)", text)
#      3         1     583600.0 583600.0      0.1      regex_items = re.compile(r"(> +Item|>Item|^Item|ITEM)((\s|&#160;|&nbsp;)(1A|1B|7A|7|8))")
#      4
#      5         1        200.0    200.0      0.0      try:
#      6         1    1741200.0 1741200.0      0.2          extracted_text = regex_10k.group(0)
#      7                                               except:
#      8                                                   print('❌ No 10-K match for file')
#      9
#     10         1       5100.0   5100.0      0.0      item_matches = regex_items.finditer(extracted_text)
#     11         1  173976200.0 173976200.0     17.2      matches_df = pd.DataFrame([(x.group(), x.start()) for x in item_matches])
#     12         1     109000.0 109000.0      0.0      matches_df.columns = ['item', 'start']
#     13         1    1115100.0 1115100.0      0.1      matches_df['item'] = matches_df['item'].str.lower().replace('>|\.| |&#160;|&nbsp|;', '', regex=True)
#     14         1     737300.0 737300.0      0.1      matches_df = matches_df.sort_values('start').drop_duplicates(subset=['item'], keep='last')
#     15         1     788500.0 788500.0      0.1      matches_df['end'] = matches_df['start'].shift(-1).fillna(0).astype(int)
#     16         1     508700.0 508700.0      0.1      matches_df = matches_df[matches_df['item'].isin(['item1a', 'item1b', 'item7', 'item7a'])]
#     17         1       1500.0   1500.0      0.0      if len(matches_df) != 4:
#     18                                                   print('❌ Only {sections} sections found for file'.format(sections=len(matches_df)))
#     19         1  720818000.0 720818000.0     71.3      matches_df['text'] = matches_df\
#     20         1        800.0    800.0      0.0          .apply(lambda row: BeautifulSoup(extracted_text[row['start']:row['end']], 'lxml').get_text('\n\n'), axis=1)
#     21
#     22         1        300.0    300.0      0.0      return matches_df

# %%
# %lprun -f process_filing process_filing(10)
# Out:
# Successfully parsed for file data/10k_raw/AEE/0001445305-13-000414.txt and ticker AEE

# %% [markdown]
# # Just doing it as a for loop

# %%
# %%timeit
for i in range(10):
    ticker = metadata.iloc[i]['TICKER']
    leaf = metadata.iloc[i]['EDGAR_LINK'].split("/")[-1]
    
    input_file_name = os.path.join(input_dir,
                             ticker, leaf)
    with open(input_file_name, 'r', encoding='utf-8') as f:
        file = f.read()
    
    try:
        clean_df = parse_filing(file)
    
        destination_file = os.path.join(destination_dir, ticker, leaf)

        destination_subdir = os.path.dirname(destination_file)

        if not os.path.isdir(destination_subdir):
            os.makedirs(destination_subdir)

        clean_df.to_csv(destination_file)
        print('Successfully parsed for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        
    except Exception as e:
        print('Failed parse for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        print(e)
        print('\n')
# Out:
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# 3.22 s ± 154 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Multiprocessing with Pool

# %%
# %%timeit
with Pool(processes=4) as pool:
    pool.map(process_filing, range(10))
# Out:
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTXSuccessfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
#
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMOSuccessfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
#
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# 1.81 s ± 179 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Cythonized

# %%
# %load_ext Cython

# %%
# %%cython
#
# import pandas as pd
# import cython
# import os
# import re
# import json
# from bs4 import BeautifulSoup
# from multiprocessing import Pool
#
# os.chdir('/mnt/d/workspace/8-2/Financial-Statements-Text-Analysis/')
#
# # params
# with open('config.json', 'r') as f:
#     c = json.load(f)
# input_dir = os.path.join(c['DATA_DIR'], '10k_raw')
# destination_dir = os.path.join(c['DATA_DIR'], '10k_clean')
#
# metadata = pd.read_csv(os.path.join(c['DATA_DIR'], 'metadata.csv'))
# metadata_legacy = pd.read_csv(os.path.join(c['DATA_DIR'], 'metadata_2017.csv'))
#
# # only download the data from russell 3000 today
# metadata = metadata_legacy[metadata_legacy['TICKER'].isin(metadata['ticker'])]
#
# def parse_filing(text):
#     regex_10k = re.search(r"(?s)(?m)<TYPE>10-K.*?(</TEXT>)", text)
#     regex_items = re.compile(r"(> +Item|>Item|^Item|ITEM)((\s|&#160;|&nbsp;)(1A|1B|7A|7|8))")
#
#     try:
#         extracted_text = regex_10k.group(0)
#     except:
#         print('❌ No 10-K match for file')
#
#     item_matches = regex_items.finditer(extracted_text)
#     matches_df = pd.DataFrame([(x.group(), x.start()) for x in item_matches])
#     matches_df.columns = ['item', 'start']
#     matches_df['item'] = matches_df['item'].str.lower().replace('>|\.| |&#160;|&nbsp|;', '', regex=True)
#     matches_df = matches_df.sort_values('start').drop_duplicates(subset=['item'], keep='last')
#     matches_df['end'] = matches_df['start'].shift(-1).fillna(0).astype(int)
#     matches_df = matches_df[matches_df['item'].isin(['item1a', 'item1b', 'item7', 'item7a'])]
#     if len(matches_df) != 4:
#         print('❌ Only {sections} sections found for file'.format(sections=len(matches_df)))
#     matches_df['text'] = matches_df\
#         .apply(lambda row: BeautifulSoup(extracted_text[row['start']:row['end']], 'lxml').get_text('\n\n'), axis=1)
#
#     return matches_df
#
# def process_filing(i):
#     ticker = metadata.iloc[i]['TICKER']
#     leaf = metadata.iloc[i]['EDGAR_LINK'].split("/")[-1]
#
#     input_file_name = os.path.join(input_dir,
#                              ticker, leaf)
#     with open(input_file_name, 'r', encoding='utf-8') as f:
#         file = f.read()
#
#     try:
#         clean_df = parse_filing(file)
#
#         destination_file = os.path.join(destination_dir, ticker, leaf)
#
#         destination_subdir = os.path.dirname(destination_file)
#
#         if not os.path.isdir(destination_subdir):
#             os.makedirs(destination_subdir)
#
#         clean_df.to_csv(destination_file)
#         print('Successfully parsed for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
#
#     except Exception as e:
#         print('Failed parse for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
#         print(e)
#         print('\n')

# %%
# %%timeit 
with Pool(processes=4) as pool:
    pool.map(process_filing, range(10))
# Out:
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSPSuccessfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
#
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# 2.54 s ± 31.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
for i in range(10):
    ticker = metadata.iloc[i]['TICKER']
    leaf = metadata.iloc[i]['EDGAR_LINK'].split("/")[-1]
    
    input_file_name = os.path.join(input_dir,
                             ticker, leaf)
    with open(input_file_name, 'r', encoding='utf-8') as f:
        file = f.read()
    
    try:
        clean_df = parse_filing(file)
    
        destination_file = os.path.join(destination_dir, ticker, leaf)

        destination_subdir = os.path.dirname(destination_file)

        if not os.path.isdir(destination_subdir):
            os.makedirs(destination_subdir)

        clean_df.to_csv(destination_file)
        print('Successfully parsed for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        
    except Exception as e:
        print('Failed parse for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        print(e)
        print('\n')
# Out:
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# 4.39 s ± 77.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Cython with declarations

# %%
# %%cython
#
# import pandas as pd
# import cython
# import os
# import re
# import json
# from bs4 import BeautifulSoup
# from multiprocessing import Pool
#
# os.chdir('/mnt/d/workspace/8-2/Financial-Statements-Text-Analysis/')
#
# # params
# with open('config.json', 'r') as f:
#     c = json.load(f)
# input_dir = os.path.join(c['DATA_DIR'], '10k_raw')
# destination_dir = os.path.join(c['DATA_DIR'], '10k_clean')
#
# metadata = pd.read_csv(os.path.join(c['DATA_DIR'], 'metadata.csv'))
# metadata_legacy = pd.read_csv(os.path.join(c['DATA_DIR'], 'metadata_2017.csv'))
#
# # only download the data from russell 3000 today
# metadata = metadata_legacy[metadata_legacy['TICKER'].isin(metadata['ticker'])]
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def parse_filing_cython(text):
#     cdef str extracted_text
#     cdef int start, end, sections
#     cdef Py_ssize_t i, n
#
#     regex_10k = re.compile(r"(?s)(?m)<TYPE>10-K.*?(</TEXT>)")
#     regex_items = re.compile(r"(> +Item|>Item|^Item|ITEM)((\s|&#160;|&nbsp;)(1A|1B|7A|7|8))")
#
#     try:
#         extracted_text = regex_10k.search(text).group(0)
#     except:
#         print('❌ No 10-K match for file')
#
#     item_matches = regex_items.finditer(extracted_text)
#     matches_df = pd.DataFrame([(x.group(), x.start()) for x in item_matches])
#     matches_df.columns = ['item', 'start']
#     matches_df['item'] = matches_df['item'].str.lower().replace('>|\.| |&#160;|&nbsp|;', '', regex=True)
#     matches_df = matches_df.sort_values('start').drop_duplicates(subset=['item'], keep='last')
#     matches_df['end'] = matches_df['start'].shift(-1).fillna(0).astype(int)
#     matches_df = matches_df[matches_df['item'].isin(['item1a', 'item1b', 'item7', 'item7a'])]
#     n = len(matches_df)
#     if n != 4:
#         print('❌ Only {sections} sections found for file'.format(sections=n))
#     for i in range(n):
#         start = matches_df.iloc[i]['start']
#         end = matches_df.iloc[i+1]['start'] if i+1<n else 0
#         matches_df.at[i, 'text'] = BeautifulSoup(extracted_text[start:end], 'lxml').get_text('\n\n')
#
#     return matches_df
#
# def process_filing(i):
#     ticker = metadata.iloc[i]['TICKER']
#     leaf = metadata.iloc[i]['EDGAR_LINK'].split("/")[-1]
#
#     input_file_name = os.path.join(input_dir,
#                              ticker, leaf)
#     with open(input_file_name, 'r', encoding='utf-8') as f:
#         file = f.read()
#
#     try:
#         clean_df = parse_filing_cython(file)
#
#         destination_file = os.path.join(destination_dir, ticker, leaf)
#
#         destination_subdir = os.path.dirname(destination_file)
#
#         if not os.path.isdir(destination_subdir):
#             os.makedirs(destination_subdir)
#
#         clean_df.to_csv(destination_file)
#         print('Successfully parsed for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
#
#     except Exception as e:
#         print('Failed parse for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
#         print(e)
#         print('\n')

# %%
# %%timeit
with Pool(processes=4) as pool:
    pool.map(process_filing, range(10))
# Out:
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSPSuccessfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
#
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSICSuccessfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
#
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTXSuccessfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
#
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSGSuccessfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
#
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# 3.27 s ± 190 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Batch all files to process

# %%
for i in range(len(metadata)):
    ticker = metadata.iloc[i]['TICKER']
    leaf = metadata.iloc[i]['EDGAR_LINK'].split("/")[-1]
    
    input_file_name = os.path.join(input_dir,
                             ticker, leaf)
    with open(input_file_name, 'r', encoding='utf-8') as f:
        file = f.read()
    
    try:
        clean_df = parse_filing(file)
    
        destination_file = os.path.join(destination_dir, ticker, leaf)

        destination_subdir = os.path.dirname(destination_file)

        if not os.path.isdir(destination_subdir):
            os.makedirs(destination_subdir)

        clean_df.to_csv(destination_file, index=False)
        print('Successfully parsed for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        
    except Exception as e:
        print('Failed parse for file {} and ticker {}'.format(input_file_name, metadata.iloc[i]['TICKER']))
        print(e)
        print('\n')
# Out:
# Successfully parsed for file data/10k_raw/HSIC/0001000228-13-000010.txt and ticker HSIC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NVAX/0001144204-13-014545.txt and ticker NVAX
# Successfully parsed for file data/10k_raw/WAT/0001193125-13-076804.txt and ticker WAT
# Successfully parsed for file data/10k_raw/NSP/0001140361-13-005779.txt and ticker NSP
# Successfully parsed for file data/10k_raw/DISH/0001104659-13-011967.txt and ticker DISH
# Successfully parsed for file data/10k_raw/SGMO/0001193125-13-076887.txt and ticker SGMO
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/TGTX/0001144204-13-016691.txt and ticker TGTX
# Successfully parsed for file data/10k_raw/NWPX/0001193125-13-112587.txt and ticker NWPX
# Successfully parsed for file data/10k_raw/SCCO/0001104659-13-015720.txt and ticker SCCO
# Successfully parsed for file data/10k_raw/INSG/0001144204-13-013543.txt and ticker INSG
# Successfully parsed for file data/10k_raw/AEE/0001445305-13-000414.txt and ticker AEE
# Successfully parsed for file data/10k_raw/AMG/0001047469-13-001515.txt and ticker AMG
# Successfully parsed for file data/10k_raw/OCFC/0001193125-13-109142.txt and ticker OCFC
# Successfully parsed for file data/10k_raw/PCG/0001004980-13-000013.txt and ticker PCG
# Successfully parsed for file data/10k_raw/UAL/0001193125-13-074391.txt and ticker UAL
# Successfully parsed for file data/10k_raw/DCOM/0001005409-13-000012.txt and ticker DCOM
# Successfully parsed for file data/10k_raw/CSGS/0001193125-13-096335.txt and ticker CSGS
# Successfully parsed for file data/10k_raw/TMP/0001387131-13-000822.txt and ticker TMP
# Successfully parsed for file data/10k_raw/TUP/0001008654-13-000008.txt and ticker TUP
# Successfully parsed for file data/10k_raw/UNP/0001193125-13-045658.txt and ticker UNP
# Successfully parsed for file data/10k_raw/SIGA/0001010086-13-000004.txt and ticker SIGA
# Successfully parsed for file data/10k_raw/UFCS/0000101199-13-000014.txt and ticker UFCS
# Successfully parsed for file data/10k_raw/SEE/0001193125-13-087879.txt and ticker SEE
# Successfully parsed for file data/10k_raw/ANSS/0001013462-13-000003.txt and ticker ANSS
# Successfully parsed for file data/10k_raw/BJRI/0001193125-13-074282.txt and ticker BJRI
# Successfully parsed for file data/10k_raw/UMBF/0001193125-13-073860.txt and ticker UMBF
# Successfully parsed for file data/10k_raw/PEGA/0001193125-13-067337.txt and ticker PEGA
# Successfully parsed for file data/10k_raw/NRG/0001013871-13-000003.txt and ticker NRG
# Successfully parsed for file data/10k_raw/TTEC/0001104659-13-014418.txt and ticker TTEC
# Successfully parsed for file data/10k_raw/STRA/0001213900-13-000794.txt and ticker STRA
# Successfully parsed for file data/10k_raw/VRSN/0001014473-13-000006.txt and ticker VRSN
# Successfully parsed for file data/10k_raw/WTFC/0001015328-13-000073.txt and ticker WTFC
# Successfully parsed for file data/10k_raw/CSV/0001445305-13-000649.txt and ticker CSV
# Successfully parsed for file data/10k_raw/MRO/0000101778-13-000006.txt and ticker MRO
# Successfully parsed for file data/10k_raw/S/0000101830-13-000006.txt and ticker S
# Successfully parsed for file data/10k_raw/EBTC/0001018399-13-000011.txt and ticker EBTC
# Successfully parsed for file data/10k_raw/AMZN/0001193125-13-028520.txt and ticker AMZN
# Successfully parsed for file data/10k_raw/ATI/0001193125-13-084310.txt and ticker ATI
# Successfully parsed for file data/10k_raw/AMSF/0001193125-13-094153.txt and ticker AMSF
# Successfully parsed for file data/10k_raw/PAG/0001104659-13-016197.txt and ticker PAG
# Successfully parsed for file data/10k_raw/CERS/0001193125-13-103031.txt and ticker CERS
# Successfully parsed for file data/10k_raw/IRM/0001047469-13-002039.txt and ticker IRM
# Successfully parsed for file data/10k_raw/DXPE/0001020710-13-000008.txt and ticker DXPE
# Successfully parsed for file data/10k_raw/NUS/0001021561-13-000033.txt and ticker NUS
# Successfully parsed for file data/10k_raw/OGE/0001021635-13-000018.txt and ticker OGE
# Successfully parsed for file data/10k_raw/NOV/0001193125-13-070840.txt and ticker NOV
# Successfully parsed for file data/10k_raw/DGX/0001022079-13-000014.txt and ticker DGX
# Successfully parsed for file data/10k_raw/UVSP/0001193125-13-089571.txt and ticker UVSP
# Successfully parsed for file data/10k_raw/STLD/0001047469-13-001827.txt and ticker STLD
# Successfully parsed for file data/10k_raw/ANIP/0001104659-13-016148.txt and ticker ANIP
# Successfully parsed for file data/10k_raw/LAD/0001437749-13-001877.txt and ticker LAD
# Successfully parsed for file data/10k_raw/FORR/0001193125-13-112678.txt and ticker FORR
# Successfully parsed for file data/10k_raw/WPC/0001104659-13-014285.txt and ticker WPC
# Successfully parsed for file data/10k_raw/EFSC/0001025835-13-000014.txt and ticker EFSC
# Successfully parsed for file data/10k_raw/KRC/0001025996-13-000036.txt and ticker KRC
# Successfully parsed for file data/10k_raw/VMI/0001047469-13-001680.txt and ticker VMI
# Successfully parsed for file data/10k_raw/VSEC/0000102752-13-000009.txt and ticker VSEC
# Successfully parsed for file data/10k_raw/PPBI/0001028918-13-000022.txt and ticker PPBI
# Successfully parsed for file data/10k_raw/DVAX/0001193125-13-098862.txt and ticker DVAX
# Successfully parsed for file data/10k_raw/EEFT/0001029199-13-000008.txt and ticker EEFT
# Successfully parsed for file data/10k_raw/OFG/0001030469-13-000015.txt and ticker OFG
# Successfully parsed for file data/10k_raw/GPI/0001031203-13-000004.txt and ticker GPI
# Successfully parsed for file data/10k_raw/FE/0001031296-13-000010.txt and ticker FE
# Successfully parsed for file data/10k_raw/FSP/0001104659-13-011834.txt and ticker FSP
# Successfully parsed for file data/10k_raw/SLM/0001193125-13-076990.txt and ticker SLM
# Successfully parsed for file data/10k_raw/SRE/0000086521-13-000014.txt and ticker SRE
# Successfully parsed for file data/10k_raw/VFC/0001193125-13-079974.txt and ticker VFC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/SBAC/0001193125-13-080059.txt and ticker SBAC
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/VLO/0001035002-13-000008.txt and ticker VLO
# Successfully parsed for file data/10k_raw/SHBI/0001144204-13-015234.txt and ticker SHBI
# Successfully parsed for file data/10k_raw/CWT/0001047469-13-001968.txt and ticker CWT
# Successfully parsed for file data/10k_raw/ISRG/0001193125-13-036675.txt and ticker ISRG
# Successfully parsed for file data/10k_raw/ARE/0001104659-13-014040.txt and ticker ARE
# Successfully parsed for file data/10k_raw/SEM/0001047469-13-001696.txt and ticker SEM
# Successfully parsed for file data/10k_raw/FIX/0001047469-13-001962.txt and ticker FIX
# Successfully parsed for file data/10k_raw/VSH/0000103730-13-000009.txt and ticker VSH
# Successfully parsed for file data/10k_raw/BXP/0001193125-13-084781.txt and ticker BXP
# Successfully parsed for file data/10k_raw/MTD/0001037646-13-000005.txt and ticker MTD
# Successfully parsed for file data/10k_raw/ACI/0001047469-13-002059.txt and ticker ACI
# Successfully parsed for file data/10k_raw/AME/0001193125-13-069307.txt and ticker AME
# Successfully parsed for file data/10k_raw/JLL/0001140361-13-009386.txt and ticker JLL
# Successfully parsed for file data/10k_raw/SLAB/0001047469-13-000608.txt and ticker SLAB
# Successfully parsed for file data/10k_raw/HSKA/0001193125-13-108014.txt and ticker HSKA
# Successfully parsed for file data/10k_raw/PXD/0001038357-13-000009.txt and ticker PXD
# Successfully parsed for file data/10k_raw/FORM/0001445305-13-000585.txt and ticker FORM
# Successfully parsed for file data/10k_raw/OKE/0001039684-13-000024.txt and ticker OKE
# Successfully parsed for file data/10k_raw/AEL/0001039828-13-000035.txt and ticker AEL
# Successfully parsed for file data/10k_raw/RHP/0001193125-13-079938.txt and ticker RHP
# Successfully parsed for file data/10k_raw/SLG/0001047469-13-001830.txt and ticker SLG
# Successfully parsed for file data/10k_raw/YUM/0001041061-13-000007.txt and ticker YUM
# Successfully parsed for file data/10k_raw/WMT/0000104169-13-000011.txt and ticker WMT
# Successfully parsed for file data/10k_raw/PLCE/0001445305-13-000737.txt and ticker PLCE
# Successfully parsed for file data/10k_raw/AFG/0001042046-13-000007.txt and ticker AFG
# Successfully parsed for file data/10k_raw/MBWM/0001193125-13-106327.txt and ticker MBWM
# Successfully parsed for file data/10k_raw/PDM/0001042776-13-000009.txt and ticker PDM
# Successfully parsed for file data/10k_raw/DRQ/0001193125-13-081240.txt and ticker DRQ
# Successfully parsed for file data/10k_raw/NLY/0001157523-13-001038.txt and ticker NLY
# Successfully parsed for file data/10k_raw/CHRW/0001043277-13-000004.txt and ticker CHRW
# Successfully parsed for file data/10k_raw/SRI/0001144204-13-014041.txt and ticker SRI
# Successfully parsed for file data/10k_raw/SAH/0001193125-13-127041.txt and ticker SAH
# Successfully parsed for file data/10k_raw/JNPR/0001043604-13-000022.txt and ticker JNPR
# Successfully parsed for file data/10k_raw/EPR/0001045450-13-000019.txt and ticker EPR
# Successfully parsed for file data/10k_raw/BAX/0001193125-13-069609.txt and ticker BAX
# Successfully parsed for file data/10k_raw/NVDA/0001045810-13-000008.txt and ticker NVDA
# Successfully parsed for file data/10k_raw/HFWA/0001193125-13-093956.txt and ticker HFWA
# Successfully parsed for file data/10k_raw/INGR/0001104659-13-015305.txt and ticker INGR
# Successfully parsed for file data/10k_raw/CHH/0001046311-13-000003.txt and ticker CHH
# Successfully parsed for file data/10k_raw/AMKR/0001047127-13-000007.txt and ticker AMKR
# Successfully parsed for file data/10k_raw/URI/0001067701-13-000004.txt and ticker URI
# Successfully parsed for file data/10k_raw/NHC/0001047335-13-000021.txt and ticker NHC
# Successfully parsed for file data/10k_raw/FDP/0001445305-13-000252.txt and ticker FDP
# Successfully parsed for file data/10k_raw/ED/0001193125-13-069310.txt and ticker ED
# Successfully parsed for file data/10k_raw/MAR/0001445305-13-000255.txt and ticker MAR
# Successfully parsed for file data/10k_raw/BMRN/0001193125-13-077031.txt and ticker BMRN
# Successfully parsed for file data/10k_raw/AVA/0000104918-13-000042.txt and ticker AVA
# Successfully parsed for file data/10k_raw/MKSI/0001193125-13-077234.txt and ticker MKSI
# Successfully parsed for file data/10k_raw/BRKL/0001047469-13-002073.txt and ticker BRKL
# Successfully parsed for file data/10k_raw/WSO/0001193125-13-084635.txt and ticker WSO
# Successfully parsed for file data/10k_raw/EGBN/0001047469-13-002980.txt and ticker EGBN
# Successfully parsed for file data/10k_raw/MSTR/0001193125-13-055763.txt and ticker MSTR
# Successfully parsed for file data/10k_raw/PGC/0000914317-13-000318.txt and ticker PGC
# Successfully parsed for file data/10k_raw/COLM/0001050797-13-000003.txt and ticker COLM
# Successfully parsed for file data/10k_raw/PWR/0001193125-13-087221.txt and ticker PWR
# Successfully parsed for file data/10k_raw/CCI/0001051470-13-000007.txt and ticker CCI
# Successfully parsed for file data/10k_raw/TDS/0001047469-13-001701.txt and ticker TDS
# Successfully parsed for file data/10k_raw/AXTI/0001140361-13-012640.txt and ticker AXTI
# Successfully parsed for file data/10k_raw/GTY/0001193125-13-112263.txt and ticker GTY
# Successfully parsed for file data/10k_raw/WTW/0001193125-13-079926.txt and ticker WTW
# Successfully parsed for file data/10k_raw/HTBK/0001047469-13-002422.txt and ticker HTBK
# Successfully parsed for file data/10k_raw/AMT/0001193125-13-077821.txt and ticker AMT
# Successfully parsed for file data/10k_raw/CRAI/0001047469-13-002423.txt and ticker CRAI
# ❌ Only 1 sections found for file
# Successfully parsed for file data/10k_raw/WMK/0000105418-13-000008.txt and ticker WMK
# Successfully parsed for file data/10k_raw/MFA/0001104659-13-017869.txt and ticker MFA
# Successfully parsed for file data/10k_raw/EME/0000105634-13-000042.txt and ticker EME
# Successfully parsed for file data/10k_raw/MANH/0001193125-13-071744.txt and ticker MANH
# Successfully parsed for file data/10k_raw/AWR/0001104659-13-016827.txt and ticker AWR
# Successfully parsed for file data/10k_raw/CSGP/0001057352-13-000013.txt and ticker CSGP
# Successfully parsed for file data/10k_raw/WST/0000105770-13-000007.txt and ticker WST
# Successfully parsed for file data/10k_raw/IDA/0001057877-13-000040.txt and ticker IDA
# Successfully parsed for file data/10k_raw/MRVL/0001193125-13-134707.txt and ticker MRVL
# Successfully parsed for file data/10k_raw/CMG/0001193125-13-046377.txt and ticker CMG
# Successfully parsed for file data/10k_raw/CTSH/0001193125-13-077271.txt and ticker CTSH
# Successfully parsed for file data/10k_raw/MCO/0001193125-13-074571.txt and ticker MCO
# Successfully parsed for file data/10k_raw/RSG/0001060391-13-000011.txt and ticker RSG
# Successfully parsed for file data/10k_raw/SGEN/0001193125-13-080019.txt and ticker SGEN
# Successfully parsed for file data/10k_raw/CRI/0001060822-13-000008.txt and ticker CRI
# Successfully parsed for file data/10k_raw/BXMT/0001193805-13-000696.txt and ticker BXMT
# Successfully parsed for file data/10k_raw/CYTK/0001193125-13-109579.txt and ticker CYTK
# Successfully parsed for file data/10k_raw/AXL/0001062231-13-000011.txt and ticker AXL
# Successfully parsed for file data/10k_raw/HT/0001140361-13-008942.txt and ticker HT
# Successfully parsed for file data/10k_raw/SPG/0001047469-13-001862.txt and ticker SPG
# Successfully parsed for file data/10k_raw/BTU/0001064728-13-000014.txt and ticker BTU
# Successfully parsed for file data/10k_raw/EBAY/0001065088-13-000004.txt and ticker EBAY
# Successfully parsed for file data/10k_raw/NFLX/0001065280-13-000008.txt and ticker NFLX
# Successfully parsed for file data/10k_raw/WY/0000106535-13-000011.txt and ticker WY
# Successfully parsed for file data/10k_raw/LKQ/0001065696-13-000014.txt and ticker LKQ
# Successfully parsed for file data/10k_raw/SKX/0001193125-13-087817.txt and ticker SKX
# Successfully parsed for file data/10k_raw/WHR/0000106640-13-000009.txt and ticker WHR
# Successfully parsed for file data/10k_raw/HSII/0001193125-13-109907.txt and ticker HSII
# Successfully parsed for file data/10k_raw/URI/0001067701-13-000004.txt and ticker URI
# Successfully parsed for file data/10k_raw/INSP/0001193125-13-096577.txt and ticker INSP
# Successfully parsed for file data/10k_raw/EWBC/0001104659-13-016095.txt and ticker EWBC
# Successfully parsed for file data/10k_raw/LII/0001069202-13-000003.txt and ticker LII
# Successfully parsed for file data/10k_raw/KTOS/0001069258-13-000007.txt and ticker KTOS
# Successfully parsed for file data/10k_raw/TREX/0001193125-13-064375.txt and ticker TREX
# Successfully parsed for file data/10k_raw/CNX/0001070412-13-000011.txt and ticker CNX
# Successfully parsed for file data/10k_raw/ACAD/0001193125-13-103111.txt and ticker ACAD
# Successfully parsed for file data/10k_raw/HST/0001193125-13-073292.txt and ticker HST
# Successfully parsed for file data/10k_raw/CXW/0001193125-13-080296.txt and ticker CXW
# Successfully parsed for file data/10k_raw/CNC/0001071739-13-000024.txt and ticker CNC
# Successfully parsed for file data/10k_raw/WMB/0001193125-13-080025.txt and ticker WMB
# Successfully parsed for file data/10k_raw/NEO/0001193125-13-068680.txt and ticker NEO
# Successfully parsed for file data/10k_raw/INSW/0001437749-13-002777.txt and ticker INSW
# Successfully parsed for file data/10k_raw/TCBI/0001193125-13-068855.txt and ticker TCBI
# Successfully parsed for file data/10k_raw/UMPQ/0001077771-13-000041.txt and ticker UMPQ
# Successfully parsed for file data/10k_raw/INFA/0001080099-13-000006.txt and ticker INFA
# Successfully parsed for file data/10k_raw/UTHR/0001047469-13-001660.txt and ticker UTHR
# Successfully parsed for file data/10k_raw/JEF/0001193125-13-027253.txt and ticker JEF
# Successfully parsed for file data/10k_raw/ECPG/0001193125-13-055397.txt and ticker ECPG
# Successfully parsed for file data/10k_raw/PRFT/0001085869-13-000007.txt and ticker PRFT
# Successfully parsed for file data/10k_raw/AKAM/0001266432-13-000021.txt and ticker AKAM
# Successfully parsed for file data/10k_raw/XRX/0000108772-13-000006.txt and ticker XRX
# Successfully parsed for file data/10k_raw/CORT/0001193125-13-110085.txt and ticker CORT
# Successfully parsed for file data/10k_raw/DKS/0001047469-13-003238.txt and ticker DKS
# Successfully parsed for file data/10k_raw/YORW/0000108985-13-000024.txt and ticker YORW
# Successfully parsed for file data/10k_raw/SFST/0001145443-13-000778.txt and ticker SFST
# Successfully parsed for file data/10k_raw/DVN/0001193125-13-068817.txt and ticker DVN
# Successfully parsed for file data/10k_raw/LAMR/0001193125-13-084458.txt and ticker LAMR
# Successfully parsed for file data/10k_raw/UPS/0001090727-13-000005.txt and ticker UPS
# Successfully parsed for file data/10k_raw/CHTR/0001091667-13-000020.txt and ticker CHTR
# Successfully parsed for file data/10k_raw/CIR/0001091883-13-000005.txt and ticker CIR
# Successfully parsed for file data/10k_raw/WWE/0001445305-13-000441.txt and ticker WWE
# Successfully parsed for file data/10k_raw/SPSC/0001193125-13-093885.txt and ticker SPSC
# Successfully parsed for file data/10k_raw/DXCM/0001193125-13-069590.txt and ticker DXCM
# Successfully parsed for file data/10k_raw/ZION/0000109380-13-000081.txt and ticker ZION
# Successfully parsed for file data/10k_raw/TDY/0001094285-13-000064.txt and ticker TDY
# Successfully parsed for file data/10k_raw/BGCP/0001193125-13-101758.txt and ticker BGCP
# Successfully parsed for file data/10k_raw/RE/0001095073-13-000015.txt and ticker RE
# Successfully parsed for file data/10k_raw/HSTM/0001193125-13-086559.txt and ticker HSTM
# Failed parse for file data/10k_raw/MKL/0001096343-13-000005.txt and ticker MKL
# Length mismatch: Expected axis has 0 elements, new values have 2 elements
#
#
# Successfully parsed for file data/10k_raw/ALGN/0001097149-13-000007.txt and ticker ALGN
# Successfully parsed for file data/10k_raw/AGEN/0001445305-13-000644.txt and ticker AGEN
# Successfully parsed for file data/10k_raw/MET/0001193125-13-077792.txt and ticker MET
# Successfully parsed for file data/10k_raw/EW/0001047469-13-001954.txt and ticker EW
# Successfully parsed for file data/10k_raw/CRL/0001445305-13-000358.txt and ticker CRL
# Successfully parsed for file data/10k_raw/EQIX/0001193125-13-076572.txt and ticker EQIX
# Successfully parsed for file data/10k_raw/ENTG/0001193125-13-071771.txt and ticker ENTG
# Successfully parsed for file data/10k_raw/PACW/0001047469-13-001982.txt and ticker PACW
# Successfully parsed for file data/10k_raw/LPSN/0001144204-13-012330.txt and ticker LPSN
# Successfully parsed for file data/10k_raw/MDLZ/0001193125-13-073227.txt and ticker MDLZ
# Successfully parsed for file data/10k_raw/INSM/0001140361-13-012797.txt and ticker INSM
# Successfully parsed for file data/10k_raw/MTRN/0001104657-13-000047.txt and ticker MTRN
# Successfully parsed for file data/10k_raw/WWW/0001193125-13-079739.txt and ticker WWW
# Successfully parsed for file data/10k_raw/QLYS/0001107843-13-000003.txt and ticker QLYS
# Successfully parsed for file data/10k_raw/CYH/0001193125-13-080110.txt and ticker CYH
# Successfully parsed for file data/10k_raw/BHLB/0001104659-13-021671.txt and ticker BHLB
# Successfully parsed for file data/10k_raw/PNM/0001108426-13-000011.txt and ticker PNM
# Successfully parsed for file data/10k_raw/CRM/0001193125-13-098852.txt and ticker CRM
# Successfully parsed for file data/10k_raw/EVC/0001193125-13-099296.txt and ticker EVC
# Successfully parsed for file data/10k_raw/HAFC/0001193125-13-108597.txt and ticker HAFC
# Successfully parsed for file data/10k_raw/BRKR/0001047469-13-001958.txt and ticker BRKR
# Successfully parsed for file data/10k_raw/EXC/0001193125-13-069749.txt and ticker EXC
# Successfully parsed for file data/10k_raw/ILMN/0001110803-13-000095.txt and ticker ILMN
# Successfully parsed for file data/10k_raw/VC/0001111335-13-000004.txt and ticker VC
# Successfully parsed for file data/10k_raw/NI/0001111711-13-000007.txt and ticker NI
# Successfully parsed for file data/10k_raw/IPGP/0001193125-13-084799.txt and ticker IPGP
# Successfully parsed for file data/10k_raw/TROW/0001113169-13-000010.txt and ticker TROW
# Successfully parsed for file data/10k_raw/ACLS/0001047469-13-002045.txt and ticker ACLS
# Successfully parsed for file data/10k_raw/PNFP/0001140361-13-008936.txt and ticker PNFP
# Successfully parsed for file data/10k_raw/DNB/0001115222-13-000004.txt and ticker DNB
# Successfully parsed for file data/10k_raw/OSUR/0001193125-13-105190.txt and ticker OSUR
# Successfully parsed for file data/10k_raw/TTMI/0001193125-13-087442.txt and ticker TTMI
# Successfully parsed for file data/10k_raw/NDAQ/0001193125-13-069357.txt and ticker NDAQ
# Successfully parsed for file data/10k_raw/PDFS/0001437749-13-003135.txt and ticker PDFS
# Successfully parsed for file data/10k_raw/OIS/0001437749-13-001751.txt and ticker OIS
# Successfully parsed for file data/10k_raw/GRMN/0001144204-13-011527.txt and ticker GRMN
# Successfully parsed for file data/10k_raw/NTGR/0001122904-13-000009.txt and ticker NTGR
# Successfully parsed for file data/10k_raw/EXAS/0001047469-13-002072.txt and ticker EXAS
# Successfully parsed for file data/10k_raw/FLR/0001047469-13-001314.txt and ticker FLR
# Successfully parsed for file data/10k_raw/VMW/0001124610-13-000009.txt and ticker VMW
# Successfully parsed for file data/10k_raw/MDRX/0001193125-13-087986.txt and ticker MDRX
# Successfully parsed for file data/10k_raw/ENSG/0001125376-13-000022.txt and ticker ENSG
# Successfully parsed for file data/10k_raw/OPEN/0001047469-13-001707.txt and ticker OPEN
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/GEN/0001126294-13-000006.txt and ticker GEN
# Successfully parsed for file data/10k_raw/PFG/0001047469-13-000940.txt and ticker PFG
# Successfully parsed for file data/10k_raw/PRA/0001561231-13-000003.txt and ticker PRA
# Successfully parsed for file data/10k_raw/FLO/0001193125-13-067201.txt and ticker FLO
# Successfully parsed for file data/10k_raw/BSRR/0001144204-13-015015.txt and ticker BSRR
# Successfully parsed for file data/10k_raw/CNP/0001130310-13-000006.txt and ticker CNP
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/BKH/0001130464-13-000071.txt and ticker BKH
# Successfully parsed for file data/10k_raw/OSTK/0001047469-13-001400.txt and ticker OSTK
# Successfully parsed for file data/10k_raw/ZIP/0001193125-13-089791.txt and ticker ZIP
# Successfully parsed for file data/10k_raw/NOC/0001133421-13-000007.txt and ticker NOC
# Successfully parsed for file data/10k_raw/CVGW/0001193125-13-011959.txt and ticker CVGW
# Successfully parsed for file data/10k_raw/AIR/0001193125-13-054466.txt and ticker AIR
# Successfully parsed for file data/10k_raw/FIS/0001136893-13-000011.txt and ticker FIS
# Successfully parsed for file data/10k_raw/INFN/0001193125-13-091900.txt and ticker INFN
# Successfully parsed for file data/10k_raw/CCRN/0001157523-13-001449.txt and ticker CCRN
# Successfully parsed for file data/10k_raw/MA/0001141391-13-000003.txt and ticker MA
# Successfully parsed for file data/10k_raw/NXST/0001142417-13-000006.txt and ticker NXST
# Successfully parsed for file data/10k_raw/NUVA/0001445305-13-000348.txt and ticker NUVA
# Successfully parsed for file data/10k_raw/BG/0001047469-13-002069.txt and ticker BG
# Successfully parsed for file data/10k_raw/ABG/0001144980-13-000012.txt and ticker ABG
# Successfully parsed for file data/10k_raw/PODD/0001193125-13-083670.txt and ticker PODD
# Successfully parsed for file data/10k_raw/CME/0001156375-13-000007.txt and ticker CME
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/CCOI/0001047469-13-001769.txt and ticker CCOI
# Successfully parsed for file data/10k_raw/AAP/0001158449-13-000069.txt and ticker AAP
# Successfully parsed for file data/10k_raw/JBLU/0001158463-13-000010.txt and ticker JBLU
# Successfully parsed for file data/10k_raw/LMAT/0001193125-13-129404.txt and ticker LMAT
# Successfully parsed for file data/10k_raw/HALO/0001483813-13-000033.txt and ticker HALO
# Successfully parsed for file data/10k_raw/IRBT/0001445305-13-000226.txt and ticker IRBT
# Successfully parsed for file data/10k_raw/MGEE/0001161728-13-000001.txt and ticker MGEE
# Successfully parsed for file data/10k_raw/CUTR/0001140361-13-012682.txt and ticker CUTR
# Successfully parsed for file data/10k_raw/COP/0001193125-13-065426.txt and ticker COP
# Successfully parsed for file data/10k_raw/X/0001193125-13-061613.txt and ticker X
# Successfully parsed for file data/10k_raw/NBR/0001104659-13-016655.txt and ticker NBR
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NEM/0001193125-13-070256.txt and ticker NEM
# Successfully parsed for file data/10k_raw/NPO/0001193125-13-080164.txt and ticker NPO
# Successfully parsed for file data/10k_raw/XPO/0001193125-13-103438.txt and ticker XPO
# Successfully parsed for file data/10k_raw/VRNT/0001166388-13-000056.txt and ticker VRNT
# Successfully parsed for file data/10k_raw/CMCSA/0001193125-13-067658.txt and ticker CMCSA
# Successfully parsed for file data/10k_raw/WTBA/0001166928-13-000019.txt and ticker WTBA
# Successfully parsed for file data/10k_raw/NE/0001193125-13-074360.txt and ticker NE
# Successfully parsed for file data/10k_raw/CPSI/0001193125-13-101203.txt and ticker CPSI
# Successfully parsed for file data/10k_raw/BANC/0001193125-13-132678.txt and ticker BANC
# Successfully parsed for file data/10k_raw/DCT/0001193125-13-069475.txt and ticker DCT
# Successfully parsed for file data/10k_raw/SAFT/0001047469-13-002988.txt and ticker SAFT
# Successfully parsed for file data/10k_raw/HA/0001047469-13-000781.txt and ticker HA
# Successfully parsed for file data/10k_raw/CEVA/0001193125-13-109922.txt and ticker CEVA
# Successfully parsed for file data/10k_raw/HY/0001173514-13-000022.txt and ticker HY
# ❌ Only 1 sections found for file
# Successfully parsed for file data/10k_raw/ICE/0001193125-13-040159.txt and ticker ICE
# Successfully parsed for file data/10k_raw/WYNN/0001193125-13-087674.txt and ticker WYNN
# Successfully parsed for file data/10k_raw/FLT/0001193125-13-087935.txt and ticker FLT
# Successfully parsed for file data/10k_raw/WSR/0001175535-13-000009.txt and ticker WSR
# Successfully parsed for file data/10k_raw/SNX/0001177394-13-000010.txt and ticker SNX
# Successfully parsed for file data/10k_raw/FIVE/0001445305-13-000741.txt and ticker FIVE
# Successfully parsed for file data/10k_raw/ALNY/0001193125-13-065475.txt and ticker ALNY
# Successfully parsed for file data/10k_raw/FOLD/0001047469-13-002611.txt and ticker FOLD
# Successfully parsed for file data/10k_raw/PFS/0001193125-13-087041.txt and ticker PFS
# Successfully parsed for file data/10k_raw/MOH/0001445305-13-000387.txt and ticker MOH
# Successfully parsed for file data/10k_raw/HLF/0001193125-13-065327.txt and ticker HLF
# Successfully parsed for file data/10k_raw/PRAA/0001185348-13-000005.txt and ticker PRAA
# Successfully parsed for file data/10k_raw/TPX/0001206264-13-000006.txt and ticker TPX
# Successfully parsed for file data/10k_raw/WAL/0001193125-13-087604.txt and ticker WAL
# Successfully parsed for file data/10k_raw/AXS/0001214816-13-000012.txt and ticker AXS
# Successfully parsed for file data/10k_raw/CCK/0001219601-13-000007.txt and ticker CCK
# Successfully parsed for file data/10k_raw/BIO/0000012208-13-000007.txt and ticker BIO
# Successfully parsed for file data/10k_raw/CNO/0001224608-13-000017.txt and ticker CNO
# Successfully parsed for file data/10k_raw/CMP/0001140361-13-008641.txt and ticker CMP
# Successfully parsed for file data/10k_raw/JAZZ/0001232524-13-000010.txt and ticker JAZZ
# Successfully parsed for file data/10k_raw/GOOD/0001193125-13-065195.txt and ticker GOOD
# Successfully parsed for file data/10k_raw/GMED/0001237831-13-000013.txt and ticker GMED
# Successfully parsed for file data/10k_raw/ABR/0001047469-13-001165.txt and ticker ABR
# Successfully parsed for file data/10k_raw/NNI/0001258602-13-000022.txt and ticker NNI
# Successfully parsed for file data/10k_raw/FTNT/0001262039-13-000009.txt and ticker FTNT
# Successfully parsed for file data/10k_raw/WLK/0001262823-13-000007.txt and ticker WLK
# Successfully parsed for file data/10k_raw/HTH/0001104659-13-021261.txt and ticker HTH
# Successfully parsed for file data/10k_raw/AIZ/0001193125-13-067448.txt and ticker AIZ
# Successfully parsed for file data/10k_raw/NYMT/0001437749-13-003120.txt and ticker NYMT
# Successfully parsed for file data/10k_raw/AGO/0001273813-13-000006.txt and ticker AGO
# Successfully parsed for file data/10k_raw/MGI/0001193125-13-089758.txt and ticker MGI
# Successfully parsed for file data/10k_raw/FSLR/0001274494-13-000006.txt and ticker FSLR
# Successfully parsed for file data/10k_raw/UCTT/0001193125-13-105509.txt and ticker UCTT
# Successfully parsed for file data/10k_raw/GNW/0001193125-13-081960.txt and ticker GNW
# Successfully parsed for file data/10k_raw/MKTX/0001193125-13-069592.txt and ticker MKTX
# Successfully parsed for file data/10k_raw/BLKB/0001280058-13-000005.txt and ticker BLKB
# Successfully parsed for file data/10k_raw/MPWR/0001437749-13-002333.txt and ticker MPWR
# Successfully parsed for file data/10k_raw/RF/0001193125-13-069212.txt and ticker RF
# Successfully parsed for file data/10k_raw/NEU/0001282637-13-000003.txt and ticker NEU
# Successfully parsed for file data/10k_raw/TMUS/0001283699-13-000031.txt and ticker TMUS
# Successfully parsed for file data/10k_raw/CNS/0001284812-13-000168.txt and ticker CNS
# Successfully parsed for file data/10k_raw/KRG/0001286043-13-000015.txt and ticker KRG
# Successfully parsed for file data/10k_raw/DPZ/0001193125-13-081957.txt and ticker DPZ
# Successfully parsed for file data/10k_raw/PLOW/0001047469-13-002601.txt and ticker PLOW
# Successfully parsed for file data/10k_raw/MPW/0001193125-13-071643.txt and ticker MPW
# Successfully parsed for file data/10k_raw/WTI/0001193125-13-079296.txt and ticker WTI
# Successfully parsed for file data/10k_raw/MXL/0001193125-13-040818.txt and ticker MXL
# Successfully parsed for file data/10k_raw/GOOG/0001193125-13-028362.txt and ticker GOOG
# Successfully parsed for file data/10k_raw/MORN/0001289419-13-000059.txt and ticker MORN
# Successfully parsed for file data/10k_raw/TXRH/0001047469-13-001478.txt and ticker TXRH
# Successfully parsed for file data/10k_raw/EXR/0001047469-13-001942.txt and ticker EXR
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/HURN/0001193125-13-069461.txt and ticker HURN
# Successfully parsed for file data/10k_raw/BA/0000012927-13-000014.txt and ticker BA
# Successfully parsed for file data/10k_raw/TTGT/0001193125-13-112734.txt and ticker TTGT
# Successfully parsed for file data/10k_raw/WOLF/0001193125-13-134650.txt and ticker WOLF
# Successfully parsed for file data/10k_raw/TBBK/0000950159-13-000177.txt and ticker TBBK
# Successfully parsed for file data/10k_raw/SHO/0001104659-13-013600.txt and ticker SHO
# Successfully parsed for file data/10k_raw/ORA/0001193125-13-100991.txt and ticker ORA
# Successfully parsed for file data/10k_raw/EXLS/0001193125-13-096263.txt and ticker EXLS
# Successfully parsed for file data/10k_raw/DLR/0001193125-13-084894.txt and ticker DLR
# Successfully parsed for file data/10k_raw/CUBE/0001104659-13-016175.txt and ticker CUBE
# Successfully parsed for file data/10k_raw/DRH/0001445305-13-000424.txt and ticker DRH
# Successfully parsed for file data/10k_raw/PACB/0001193125-13-109968.txt and ticker PACB
# Successfully parsed for file data/10k_raw/LVS/0001193125-13-087854.txt and ticker LVS
# Successfully parsed for file data/10k_raw/BXC/0001188112-13-000440.txt and ticker BXC
# Successfully parsed for file data/10k_raw/LHCG/0001193125-13-112605.txt and ticker LHCG
# Successfully parsed for file data/10k_raw/CNSL/0001104659-13-019701.txt and ticker CNSL
# Successfully parsed for file data/10k_raw/CE/0001306830-13-000007.txt and ticker CE
# Successfully parsed for file data/10k_raw/HUN/0001047469-13-000888.txt and ticker HUN
# Successfully parsed for file data/10k_raw/SRC/0001308606-13-000004.txt and ticker SRC
# Successfully parsed for file data/10k_raw/WEX/0001193125-13-085019.txt and ticker WEX
# Successfully parsed for file data/10k_raw/GPRE/0001309402-13-000021.txt and ticker GPRE
# Successfully parsed for file data/10k_raw/LAZ/0001193125-13-084745.txt and ticker LAZ
# Successfully parsed for file data/10k_raw/KOP/0001193125-13-074188.txt and ticker KOP
# Successfully parsed for file data/10k_raw/BLDR/0001193125-13-087218.txt and ticker BLDR
# Successfully parsed for file data/10k_raw/ZUMZ/0001193125-13-114003.txt and ticker ZUMZ
# Successfully parsed for file data/10k_raw/TSLA/0001193125-13-096241.txt and ticker TSLA
# Successfully parsed for file data/10k_raw/SEM/0001047469-13-001696.txt and ticker SEM
# Successfully parsed for file data/10k_raw/THS/0001193125-13-069297.txt and ticker THS
# Successfully parsed for file data/10k_raw/ATRC/0001193125-13-097386.txt and ticker ATRC
# Successfully parsed for file data/10k_raw/RUTH/0001193125-13-104234.txt and ticker RUTH
# Successfully parsed for file data/10k_raw/CF/0001047469-13-001819.txt and ticker CF
# Successfully parsed for file data/10k_raw/EXPE/0001193125-13-039072.txt and ticker EXPE
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/DUK/0001326160-13-000009.txt and ticker DUK
# Successfully parsed for file data/10k_raw/WDAY/0001193125-13-122351.txt and ticker WDAY
# Successfully parsed for file data/10k_raw/BCC/0001328581-13-000015.txt and ticker BCC
# Successfully parsed for file data/10k_raw/HOMB/0001193125-13-089830.txt and ticker HOMB
# Successfully parsed for file data/10k_raw/BKD/0001332349-13-000012.txt and ticker BKD
# Successfully parsed for file data/10k_raw/CROX/0001193125-13-072829.txt and ticker CROX
# Successfully parsed for file data/10k_raw/Z/0001193125-13-071010.txt and ticker Z
# Successfully parsed for file data/10k_raw/CCO/0001334978-13-000006.txt and ticker CCO
# Successfully parsed for file data/10k_raw/LYV/0001193125-13-077102.txt and ticker LYV
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/APP/0001336545-13-000009.txt and ticker APP
# Successfully parsed for file data/10k_raw/LDOS/0001193125-13-127240.txt and ticker LDOS
# Successfully parsed for file data/10k_raw/RGP/0001338613-13-000011.txt and ticker RGP
# Successfully parsed for file data/10k_raw/PCH/0001338749-13-000007.txt and ticker PCH
# Successfully parsed for file data/10k_raw/HEES/0001193125-13-091690.txt and ticker HEES
# Successfully parsed for file data/10k_raw/YELP/0001206774-13-000790.txt and ticker YELP
# Successfully parsed for file data/10k_raw/CODI/0001193125-13-093853.txt and ticker CODI
# Successfully parsed for file data/10k_raw/CODI/0001193125-13-093853.txt and ticker CODI
# Successfully parsed for file data/10k_raw/VNDA/0001193125-13-075214.txt and ticker VNDA
# Successfully parsed for file data/10k_raw/ATEC/0001193125-13-089967.txt and ticker ATEC
# Successfully parsed for file data/10k_raw/DK/0001445305-13-000563.txt and ticker DK
# Successfully parsed for file data/10k_raw/EPAM/0001193125-13-101372.txt and ticker EPAM
# Successfully parsed for file data/10k_raw/PGTI/0001193125-13-086990.txt and ticker PGTI
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/H/0001398987-13-000017.txt and ticker H
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/SUPN/0001047469-13-002844.txt and ticker SUPN
# Successfully parsed for file data/10k_raw/KBR/0001357615-13-000006.txt and ticker KBR
# Successfully parsed for file data/10k_raw/HBI/0001193125-13-041391.txt and ticker HBI
# Successfully parsed for file data/10k_raw/EVR/0001193125-13-080314.txt and ticker EVR
# Successfully parsed for file data/10k_raw/PRIM/0001104659-13-018371.txt and ticker PRIM
# Successfully parsed for file data/10k_raw/ICFI/0001193125-13-085861.txt and ticker ICFI
# Successfully parsed for file data/10k_raw/ALGT/0001437749-13-001984.txt and ticker ALGT
# Successfully parsed for file data/10k_raw/MUSA/0001193125-13-109628.txt and ticker MUSA
# Successfully parsed for file data/10k_raw/ESGR/0001193125-13-085279.txt and ticker ESGR
# Successfully parsed for file data/10k_raw/DEI/0001364250-13-000007.txt and ticker DEI
# Successfully parsed for file data/10k_raw/HTZ/0001445305-13-000446.txt and ticker HTZ
# Successfully parsed for file data/10k_raw/BLK/0001193125-13-084957.txt and ticker BLK
# Successfully parsed for file data/10k_raw/SPR/0001047469-13-001981.txt and ticker SPR
# Successfully parsed for file data/10k_raw/PRMW/0001140361-13-013741.txt and ticker PRMW
# Successfully parsed for file data/10k_raw/WU/0001365135-13-000008.txt and ticker WU
# Successfully parsed for file data/10k_raw/AMRS/0001365916-13-000013.txt and ticker AMRS
# Successfully parsed for file data/10k_raw/COIN/0001387131-13-000775.txt and ticker COIN
# Successfully parsed for file data/10k_raw/GSAT/0001144204-13-015324.txt and ticker GSAT
# Successfully parsed for file data/10k_raw/EBS/0001367644-13-000016.txt and ticker EBS
# Successfully parsed for file data/10k_raw/CLNE/0001047469-13-001945.txt and ticker CLNE
# Successfully parsed for file data/10k_raw/ADMA/0001193805-13-000585.txt and ticker ADMA
# Successfully parsed for file data/10k_raw/OB/0001445305-13-000391.txt and ticker OB
# Successfully parsed for file data/10k_raw/OC/0001193125-13-066200.txt and ticker OC
# Successfully parsed for file data/10k_raw/GLDD/0001193125-13-134675.txt and ticker GLDD
# Successfully parsed for file data/10k_raw/NOW/0001373715-13-000004.txt and ticker NOW
# Successfully parsed for file data/10k_raw/CBOE/0001374310-13-000008.txt and ticker CBOE
# Successfully parsed for file data/10k_raw/AIMC/0001193125-13-074398.txt and ticker AIMC
# Successfully parsed for file data/10k_raw/ZGNX/0001445305-13-000623.txt and ticker ZGNX
# Successfully parsed for file data/10k_raw/PATH/0001047469-13-003503.txt and ticker PATH
# Successfully parsed for file data/10k_raw/CVI/0001047469-13-002747.txt and ticker CVI
# Successfully parsed for file data/10k_raw/MDXG/0001140361-13-012765.txt and ticker MDXG
# Successfully parsed for file data/10k_raw/TA/0001047469-13-002908.txt and ticker TA
# Successfully parsed for file data/10k_raw/PRTS/0001193125-13-124321.txt and ticker PRTS
# Successfully parsed for file data/10k_raw/EIG/0001379041-13-000005.txt and ticker EIG
# Successfully parsed for file data/10k_raw/DYN/0001379895-13-000007.txt and ticker DYN
# Successfully parsed for file data/10k_raw/IBKR/0001047469-13-002439.txt and ticker IBKR
# Successfully parsed for file data/10k_raw/CNK/0001193125-13-083890.txt and ticker CNK
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/SLVM/0001493152-13-000062.txt and ticker SLVM
# Successfully parsed for file data/10k_raw/GDOT/0001386278-13-000015.txt and ticker GDOT
# Successfully parsed for file data/10k_raw/TRGP/0001140361-13-008128.txt and ticker TRGP
# Successfully parsed for file data/10k_raw/BK/0001193125-13-084562.txt and ticker BK
# Successfully parsed for file data/10k_raw/GEVO/0001193125-13-124921.txt and ticker GEVO
# Successfully parsed for file data/10k_raw/PRO/0001392972-13-000005.txt and ticker PRO
# Successfully parsed for file data/10k_raw/PSA/0001393311-13-000004.txt and ticker PSA
# Successfully parsed for file data/10k_raw/DFS/0001393612-13-000004.txt and ticker DFS
# Successfully parsed for file data/10k_raw/ES/0001047469-13-002981.txt and ticker ES
# Successfully parsed for file data/10k_raw/BX/0001193125-13-087702.txt and ticker BX
# Successfully parsed for file data/10k_raw/KAR/0001047469-13-001492.txt and ticker KAR
# Successfully parsed for file data/10k_raw/VMC/0001193125-13-084128.txt and ticker VMC
# Successfully parsed for file data/10k_raw/PCRX/0001047469-13-002336.txt and ticker PCRX
# Successfully parsed for file data/10k_raw/DM/0001193125-13-098523.txt and ticker DM
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/LULU/0001193125-13-118393.txt and ticker LULU
# Successfully parsed for file data/10k_raw/LPLA/0001397911-13-000012.txt and ticker LPLA
# Successfully parsed for file data/10k_raw/G/0001193125-13-087279.txt and ticker G
# Successfully parsed for file data/10k_raw/HCI/0001193125-13-107280.txt and ticker HCI
# Successfully parsed for file data/10k_raw/CDW/0001402057-13-000003.txt and ticker CDW
# Successfully parsed for file data/10k_raw/SSNC/0001193125-13-085529.txt and ticker SSNC
# Successfully parsed for file data/10k_raw/HCCI/0001403431-13-000007.txt and ticker HCCI
# Successfully parsed for file data/10k_raw/BMRC/0001403475-13-000017.txt and ticker BMRC
# Successfully parsed for file data/10k_raw/KKR/0001047469-13-001493.txt and ticker KKR
# Successfully parsed for file data/10k_raw/IDCC/0001405495-13-000010.txt and ticker IDCC
# Successfully parsed for file data/10k_raw/FOR/0001193125-13-107366.txt and ticker FOR
# Successfully parsed for file data/10k_raw/CALX/0001406666-13-000010.txt and ticker CALX
# Successfully parsed for file data/10k_raw/GPK/0001408075-13-000011.txt and ticker GPK
# Successfully parsed for file data/10k_raw/KW/0001408100-13-000007.txt and ticker KW
# Successfully parsed for file data/10k_raw/MSCI/0001193125-13-087988.txt and ticker MSCI
# Successfully parsed for file data/10k_raw/CIM/0001157523-13-001320.txt and ticker CIM
# Successfully parsed for file data/10k_raw/AWK/0001193125-13-085812.txt and ticker AWK
# Successfully parsed for file data/10k_raw/ALSN/0001193125-13-084136.txt and ticker ALSN
# Successfully parsed for file data/10k_raw/EFC/0001411342-13-000022.txt and ticker EFC
# Successfully parsed for file data/10k_raw/APO/0001193125-13-087670.txt and ticker APO
# Successfully parsed for file data/10k_raw/MOFG/0001412665-13-000031.txt and ticker MOFG
# Successfully parsed for file data/10k_raw/PM/0001413329-13-000019.txt and ticker PM
# Successfully parsed for file data/10k_raw/SATS/0001104659-13-011985.txt and ticker SATS
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/CRWD/0001144204-13-002844.txt and ticker CRWD
# Successfully parsed for file data/10k_raw/APLE/0001185185-13-000452.txt and ticker APLE
# Successfully parsed for file data/10k_raw/IRDM/0001144204-13-012838.txt and ticker IRDM
# Successfully parsed for file data/10k_raw/IPI/0001421461-13-000007.txt and ticker IPI
# Successfully parsed for file data/10k_raw/ERII/0001437749-13-002691.txt and ticker ERII
# Successfully parsed for file data/10k_raw/AGNC/0001423689-13-000007.txt and ticker AGNC
# Successfully parsed for file data/10k_raw/BMY/0001193125-13-061678.txt and ticker BMY
# Successfully parsed for file data/10k_raw/ARR/0001437749-13-001878.txt and ticker ARR
# Successfully parsed for file data/10k_raw/SWI/0001193125-13-065436.txt and ticker SWI
# Successfully parsed for file data/10k_raw/SFBS/0001144204-13-014641.txt and ticker SFBS
# Successfully parsed for file data/10k_raw/JBT/0001437749-13-002494.txt and ticker JBT
# Successfully parsed for file data/10k_raw/LOPE/0001193125-13-065203.txt and ticker LOPE
# Successfully parsed for file data/10k_raw/HBCP/0001193125-13-109795.txt and ticker HBCP
# Successfully parsed for file data/10k_raw/IVR/0001193125-13-087882.txt and ticker IVR
# Successfully parsed for file data/10k_raw/BFAM/0001193125-13-126728.txt and ticker BFAM
# Successfully parsed for file data/10k_raw/DMRC/0001193125-13-071702.txt and ticker DMRC
# Successfully parsed for file data/10k_raw/MRC/0001193125-13-071478.txt and ticker MRC
# Successfully parsed for file data/10k_raw/CLW/0001445305-13-000301.txt and ticker CLW
# Successfully parsed for file data/10k_raw/VRSK/0001193125-13-076934.txt and ticker VRSK
# Successfully parsed for file data/10k_raw/PRLB/0001193125-13-121462.txt and ticker PRLB
# Successfully parsed for file data/10k_raw/IRWD/0001047469-13-001388.txt and ticker IRWD
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/OPRX/0001255294-13-000182.txt and ticker OPRX
# Successfully parsed for file data/10k_raw/NE/0001193125-13-074360.txt and ticker NE
# Successfully parsed for file data/10k_raw/CNOB/0000930413-13-001905.txt and ticker CNOB
# Successfully parsed for file data/10k_raw/ENPH/0001445305-13-000492.txt and ticker ENPH
# Successfully parsed for file data/10k_raw/VUZI/0001144204-13-016162.txt and ticker VUZI
# Successfully parsed for file data/10k_raw/PMT/0001193125-13-084886.txt and ticker PMT
# Successfully parsed for file data/10k_raw/STWD/0001047469-13-001746.txt and ticker STWD
# Successfully parsed for file data/10k_raw/TWO/0001465740-13-000016.txt and ticker TWO
# Successfully parsed for file data/10k_raw/IRT/0001193125-13-105454.txt and ticker IRT
# Successfully parsed for file data/10k_raw/IR/0001466258-13-000006.txt and ticker IR
# Successfully parsed for file data/10k_raw/OTTR/0001188112-13-000505.txt and ticker OTTR
# Successfully parsed for file data/10k_raw/ARI/0001193125-13-087806.txt and ticker ARI
# Successfully parsed for file data/10k_raw/GM/0001467858-13-000025.txt and ticker GM
# Successfully parsed for file data/10k_raw/H/0001193125-13-055303.txt and ticker H
# Successfully parsed for file data/10k_raw/ADUS/0001193125-13-132519.txt and ticker ADUS
# Successfully parsed for file data/10k_raw/NWBI/0001104659-13-016545.txt and ticker NWBI
# Successfully parsed for file data/10k_raw/FAF/0001193125-13-084593.txt and ticker FAF
# Successfully parsed for file data/10k_raw/PEB/0001474098-13-000015.txt and ticker PEB
# Successfully parsed for file data/10k_raw/GNRC/0001474735-13-000006.txt and ticker GNRC
# Successfully parsed for file data/10k_raw/NBHC/0001193125-13-112824.txt and ticker NBHC
# Successfully parsed for file data/10k_raw/PRI/0001475922-13-000004.txt and ticker PRI
# Successfully parsed for file data/10k_raw/CLDT/0001193125-13-108043.txt and ticker CLDT
# Successfully parsed for file data/10k_raw/TRNO/0001193125-13-061413.txt and ticker TRNO
# Successfully parsed for file data/10k_raw/ST/0001477294-13-000012.txt and ticker ST
# Successfully parsed for file data/10k_raw/STAG/0001047469-13-002284.txt and ticker STAG
# Successfully parsed for file data/10k_raw/HPP/0001482512-13-000012.txt and ticker HPP
# Successfully parsed for file data/10k_raw/AL/0001047469-13-001939.txt and ticker AL
# Successfully parsed for file data/10k_raw/VPG/0001206774-13-001032.txt and ticker VPG
# Successfully parsed for file data/10k_raw/BOX/0001157523-13-000968.txt and ticker BOX
# Successfully parsed for file data/10k_raw/AMRC/0001488139-13-000009.txt and ticker AMRC
# Successfully parsed for file data/10k_raw/CUBI/0001193125-13-112444.txt and ticker CUBI
# Successfully parsed for file data/10k_raw/LYB/0001193125-13-051488.txt and ticker LYB
# Successfully parsed for file data/10k_raw/SBRA/0001492298-13-000009.txt and ticker SBRA
# Successfully parsed for file data/10k_raw/HZNP/0001193125-13-111071.txt and ticker HZNP
# Successfully parsed for file data/10k_raw/BC/0000014930-13-000059.txt and ticker BC
# Successfully parsed for file data/10k_raw/NFBK/0001193125-13-112474.txt and ticker NFBK
# Successfully parsed for file data/10k_raw/LAND/0001193125-13-129318.txt and ticker LAND
# Successfully parsed for file data/10k_raw/INN/0001157523-13-001043.txt and ticker INN
# Successfully parsed for file data/10k_raw/WD/0001047469-13-002970.txt and ticker WD
# Successfully parsed for file data/10k_raw/SAVE/0001498710-13-000034.txt and ticker SAVE
# Successfully parsed for file data/10k_raw/HHC/0001047469-13-001963.txt and ticker HHC
# Successfully parsed for file data/10k_raw/AAT/0001193125-13-071652.txt and ticker AAT
# Successfully parsed for file data/10k_raw/HII/0001501585-13-000003.txt and ticker HII
# Successfully parsed for file data/10k_raw/BKU/0001047469-13-001550.txt and ticker BKU
# Successfully parsed for file data/10k_raw/KMI/0001506307-13-000015.txt and ticker KMI
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/MARA/0001521536-13-000292.txt and ticker MARA
# Successfully parsed for file data/10k_raw/KOS/0001047469-13-001596.txt and ticker KOS
# Successfully parsed for file data/10k_raw/MPC/0001193125-13-084698.txt and ticker MPC
# Successfully parsed for file data/10k_raw/RLJ/0001047469-13-001965.txt and ticker RLJ
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/NCLH/0001193125-13-067341.txt and ticker NCLH
# Successfully parsed for file data/10k_raw/SXC/0001193125-13-071243.txt and ticker SXC
# Successfully parsed for file data/10k_raw/AMCX/0001514991-13-000006.txt and ticker AMCX
# Successfully parsed for file data/10k_raw/CHEF/0001193125-13-105358.txt and ticker CHEF
# ...
# Successfully parsed for file data/10k_raw/TGI/0001021162-13-000018.txt and ticker TGI
# Successfully parsed for file data/10k_raw/PLUS/0001022408-13-000025.txt and ticker PLUS
# Successfully parsed for file data/10k_raw/EGHT/0001136261-13-000259.txt and ticker EGHT
# Successfully parsed for file data/10k_raw/BFLY/0001133796-13-000038.txt and ticker BFLY
# Successfully parsed for file data/10k_raw/RL/0001037038-13-000009.txt and ticker RL
# Successfully parsed for file data/10k_raw/PETS/0001188112-13-001701.txt and ticker PETS
# Successfully parsed for file data/10k_raw/SCS/0001050825-13-000083.txt and ticker SCS
# Successfully parsed for file data/10k_raw/FBP/0001193125-13-136825.txt and ticker FBP
# Successfully parsed for file data/10k_raw/NTCT/0001193125-13-235038.txt and ticker NTCT
# Successfully parsed for file data/10k_raw/AMEH/0001144204-13-025748.txt and ticker AMEH
# ❌ Only 2 sections found for file
# Successfully parsed for file data/10k_raw/WRLD/0000108385-13-000022.txt and ticker WRLD
# Successfully parsed for file data/10k_raw/TJX/0001193125-13-138497.txt and ticker TJX
# Successfully parsed for file data/10k_raw/PLUG/0001003297-13-000101.txt and ticker PLUG
# Successfully parsed for file data/10k_raw/AMRS/0001214659-13-002057.txt and ticker AMRS
# Successfully parsed for file data/10k_raw/CYRX/0001144204-13-036463.txt and ticker CYRX
# Successfully parsed for file data/10k_raw/CVLT/0001193125-13-219425.txt and ticker CVLT
# Successfully parsed for file data/10k_raw/KMX/0001170010-13-000010.txt and ticker KMX
# Successfully parsed for file data/10k_raw/CDXS/0001445305-13-000770.txt and ticker CDXS
# Successfully parsed for file data/10k_raw/SPSC/0001144204-13-022227.txt and ticker SPSC
# Successfully parsed for file data/10k_raw/HRB/0001574842-13-000010.txt and ticker HRB
# Successfully parsed for file data/10k_raw/ICPT/0001144204-13-019166.txt and ticker ICPT
# Successfully parsed for file data/10k_raw/UPST/0001144204-13-019243.txt and ticker UPST
# Successfully parsed for file data/10k_raw/AMBA/0001193125-13-141693.txt and ticker AMBA
# Successfully parsed for file data/10k_raw/ENS/0001193125-13-237411.txt and ticker ENS
# Successfully parsed for file data/10k_raw/PBH/0001295947-13-000018.txt and ticker PBH
# Successfully parsed for file data/10k_raw/EGLE/0001144204-13-019308.txt and ticker EGLE
# Successfully parsed for file data/10k_raw/LWLG/0000943440-13-000360.txt and ticker LWLG
# Successfully parsed for file data/10k_raw/GME/0001193125-13-140443.txt and ticker GME
# Successfully parsed for file data/10k_raw/ENV/0001193125-13-259780.txt and ticker ENV
# Successfully parsed for file data/10k_raw/ORCL/0001193125-13-272832.txt and ticker ORCL
# Successfully parsed for file data/10k_raw/SPLK/0001047469-13-003746.txt and ticker SPLK
# Successfully parsed for file data/10k_raw/AVAV/0001047469-13-007199.txt and ticker AVAV
# Successfully parsed for file data/10k_raw/ULTA/0001193125-13-140116.txt and ticker ULTA
# Successfully parsed for file data/10k_raw/TITN/0001047469-13-004179.txt and ticker TITN
# Successfully parsed for file data/10k_raw/TREE/0001047469-13-003755.txt and ticker TREE
# Successfully parsed for file data/10k_raw/BAH/0001443646-13-000010.txt and ticker BAH
# Successfully parsed for file data/10k_raw/BIO/0001511164-13-000177.txt and ticker BIO
# Successfully parsed for file data/10k_raw/THR/0001489096-13-000025.txt and ticker THR
# Successfully parsed for file data/10k_raw/ALKS/0001047469-13-006422.txt and ticker ALKS
# Successfully parsed for file data/10k_raw/RH/0001193125-13-178723.txt and ticker RH
# Successfully parsed for file data/10k_raw/ACRE/0001047469-13-003686.txt and ticker ACRE
# Successfully parsed for file data/10k_raw/NVEE/0001193125-13-136806.txt and ticker NVEE
# Successfully parsed for file data/10k_raw/STZ/0000016918-13-000008.txt and ticker STZ
# Successfully parsed for file data/10k_raw/GCO/0000018498-13-000012.txt and ticker GCO
# Successfully parsed for file data/10k_raw/CVCO/0001445305-13-001462.txt and ticker CVCO
# Successfully parsed for file data/10k_raw/HAE/0000313143-13-000085.txt and ticker HAE
# Successfully parsed for file data/10k_raw/EBF/0001193125-13-214067.txt and ticker EBF
# Successfully parsed for file data/10k_raw/GM/0001193125-13-229279.txt and ticker GM
# Successfully parsed for file data/10k_raw/UHAL/0000004457-13-000016.txt and ticker UHAL
# Successfully parsed for file data/10k_raw/HWKN/0000046250-13-000007.txt and ticker HWKN
# Successfully parsed for file data/10k_raw/AM/0001193125-13-209085.txt and ticker AM
# Successfully parsed for file data/10k_raw/KFY/0001193125-13-270364.txt and ticker KFY
# Successfully parsed for file data/10k_raw/KR/0001104659-13-026395.txt and ticker KR
# Successfully parsed for file data/10k_raw/LZB/0001140361-13-025602.txt and ticker LZB
# Successfully parsed for file data/10k_raw/LOW/0000060667-13-000045.txt and ticker LOW
# Successfully parsed for file data/10k_raw/MDT/0000064670-13-000006.txt and ticker MDT
# Successfully parsed for file data/10k_raw/MOD/0001140361-13-023524.txt and ticker MOD
# Successfully parsed for file data/10k_raw/APOG/0000006845-13-000009.txt and ticker APOG
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/ACEL/0001308411-13-000092.txt and ticker ACEL
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/ACEL/0001308411-13-000095.txt and ticker ACEL
# Successfully parsed for file data/10k_raw/EA/0000712515-13-000022.txt and ticker EA
# Successfully parsed for file data/10k_raw/WSM/0001193125-13-142309.txt and ticker WSM
# Successfully parsed for file data/10k_raw/MLAB/0001104659-13-047358.txt and ticker MLAB
# Successfully parsed for file data/10k_raw/CASY/0001193125-13-274177.txt and ticker CASY
# Successfully parsed for file data/10k_raw/REX/0000930413-13-002135.txt and ticker REX
# Successfully parsed for file data/10k_raw/ROST/0000745732-13-000006.txt and ticker ROST
# Successfully parsed for file data/10k_raw/OXM/0001047469-13-003950.txt and ticker OXM
# Successfully parsed for file data/10k_raw/BIG/0000768835-13-000024.txt and ticker BIG
# Successfully parsed for file data/10k_raw/CRUS/0001193125-13-239492.txt and ticker CRUS
# Successfully parsed for file data/10k_raw/PVH/0000078239-13-000019.txt and ticker PVH
# Successfully parsed for file data/10k_raw/AGYS/0000078749-13-000023.txt and ticker AGYS
# Successfully parsed for file data/10k_raw/AMWD/0000794619-13-000024.txt and ticker AMWD
# Successfully parsed for file data/10k_raw/VSAT/0001193125-13-234043.txt and ticker VSAT
# Successfully parsed for file data/10k_raw/CRMT/0001171843-13-002561.txt and ticker CRMT
# Successfully parsed for file data/10k_raw/STE/0000815065-13-000006.txt and ticker STE
# Successfully parsed for file data/10k_raw/HRT/0000819689-13-000022.txt and ticker HRT
# Successfully parsed for file data/10k_raw/GIII/0001193125-13-153157.txt and ticker GIII
# Successfully parsed for file data/10k_raw/MCHP/0000827054-13-000171.txt and ticker MCHP
# Successfully parsed for file data/10k_raw/RAD/0001047469-13-004721.txt and ticker RAD
# Successfully parsed for file data/10k_raw/FL/0001144204-13-019239.txt and ticker FL
# Successfully parsed for file data/10k_raw/CRVL/0001193125-13-253579.txt and ticker CRVL
# Successfully parsed for file data/10k_raw/MNRO/0001193125-13-239665.txt and ticker MNRO
# Successfully parsed for file data/10k_raw/SPTN/0001193125-13-233505.txt and ticker SPTN
# Successfully parsed for file data/10k_raw/CRC/0001140361-13-025856.txt and ticker CRC
# Successfully parsed for file data/10k_raw/SMRT/0001193125-13-199332.txt and ticker SMRT
# Successfully parsed for file data/10k_raw/BKE/0001157523-13-001668.txt and ticker BKE
# Successfully parsed for file data/10k_raw/BBBY/0001104659-13-035115.txt and ticker BBBY
# Successfully parsed for file data/10k_raw/SENEA/0000088948-13-000008.txt and ticker SENEA
# Successfully parsed for file data/10k_raw/PDCO/0001193125-13-272374.txt and ticker PDCO
# Successfully parsed for file data/10k_raw/AZZ/0000008947-13-000092.txt and ticker AZZ
# Successfully parsed for file data/10k_raw/SCVL/0001174947-13-000180.txt and ticker SCVL
# Successfully parsed for file data/10k_raw/OSH/0001193125-13-199400.txt and ticker OSH
# Successfully parsed for file data/10k_raw/CWST/0001193125-13-275023.txt and ticker CWST
# Successfully parsed for file data/10k_raw/GES/0000912463-13-000006.txt and ticker GES
# Successfully parsed for file data/10k_raw/URBN/0001193125-13-136738.txt and ticker URBN
# Successfully parsed for file data/10k_raw/SJM/0001193125-13-266625.txt and ticker SJM
# Successfully parsed for file data/10k_raw/HELE/0001104659-13-034243.txt and ticker HELE
# Successfully parsed for file data/10k_raw/EXP/0001193125-13-235755.txt and ticker EXP
# Successfully parsed for file data/10k_raw/MCK/0001561787-13-000010.txt and ticker MCK
# Successfully parsed for file data/10k_raw/TTWO/0001047469-13-006006.txt and ticker TTWO
# Successfully parsed for file data/10k_raw/TDW/0001193125-13-229622.txt and ticker TDW
# Successfully parsed for file data/10k_raw/TRNS/0001171843-13-002603.txt and ticker TRNS
# Successfully parsed for file data/10k_raw/EL/0001104659-13-065820.txt and ticker EL
# Successfully parsed for file data/10k_raw/COTY/0000930413-13-004596.txt and ticker COTY
# Successfully parsed for file data/10k_raw/OSIS/0001047469-13-008515.txt and ticker OSIS
# Successfully parsed for file data/10k_raw/FDX/0001193125-13-290858.txt and ticker FDX
# Successfully parsed for file data/10k_raw/MRCY/0001049521-13-000008.txt and ticker MRCY
# Successfully parsed for file data/10k_raw/WDC/0001193125-13-338607.txt and ticker WDC
# Successfully parsed for file data/10k_raw/COCO/0001047469-13-008803.txt and ticker COCO
# Successfully parsed for file data/10k_raw/CBRL/0001140361-13-037045.txt and ticker CBRL
# Successfully parsed for file data/10k_raw/EXTR/0001078271-13-000049.txt and ticker EXTR
# Successfully parsed for file data/10k_raw/WOR/0001193125-13-310489.txt and ticker WOR
# Successfully parsed for file data/10k_raw/AIT/0000109563-13-000029.txt and ticker AIT
# Successfully parsed for file data/10k_raw/ARRY/0001100412-13-000025.txt and ticker ARRY
# Successfully parsed for file data/10k_raw/RPM/0001193125-13-300693.txt and ticker RPM
# Successfully parsed for file data/10k_raw/QNST/0001193125-13-340993.txt and ticker QNST
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/GPN/0001123360-13-000025.txt and ticker GPN
# Successfully parsed for file data/10k_raw/LRN/0001047469-13-008761.txt and ticker LRN
# Successfully parsed for file data/10k_raw/CSII/0001445305-13-002256.txt and ticker CSII
# Successfully parsed for file data/10k_raw/ANGO/0001193125-13-334608.txt and ticker ANGO
# Successfully parsed for file data/10k_raw/MOS/0001193125-13-292097.txt and ticker MOS
# Successfully parsed for file data/10k_raw/KRNY/0000946275-13-000296.txt and ticker KRNY
# Successfully parsed for file data/10k_raw/NWS/0001193125-13-338522.txt and ticker NWS
# Successfully parsed for file data/10k_raw/PANW/0001327567-13-000026.txt and ticker PANW
# Successfully parsed for file data/10k_raw/BV/0001193125-13-281660.txt and ticker BV
# Successfully parsed for file data/10k_raw/SMCI/0001445305-13-002262.txt and ticker SMCI
# Successfully parsed for file data/10k_raw/BR/0001193125-13-326099.txt and ticker BR
# Successfully parsed for file data/10k_raw/AOSL/0001387467-13-000080.txt and ticker AOSL
# Successfully parsed for file data/10k_raw/AROC/0001511164-13-000376.txt and ticker AROC
# Successfully parsed for file data/10k_raw/FN/0001193125-13-338274.txt and ticker FN
# Successfully parsed for file data/10k_raw/SMPL/0001193125-13-362733.txt and ticker SMPL
# Successfully parsed for file data/10k_raw/TW/0001193125-13-336794.txt and ticker TW
# ❌ Only 3 sections found for file
# Successfully parsed for file data/10k_raw/MRC/0001214782-13-000285.txt and ticker MRC
# Successfully parsed for file data/10k_raw/GWRE/0001528396-13-000025.txt and ticker GWRE
# Successfully parsed for file data/10k_raw/HTBI/0000927089-13-000156.txt and ticker HTBI
# Successfully parsed for file data/10k_raw/NWS/0001193125-13-373501.txt and ticker NWS
# Successfully parsed for file data/10k_raw/ITCI/0001213900-13-003641.txt and ticker ITCI
# Successfully parsed for file data/10k_raw/CACI/0001193125-13-348088.txt and ticker CACI
# Successfully parsed for file data/10k_raw/CALM/0001144204-13-042925.txt and ticker CALM
# Successfully parsed for file data/10k_raw/CPB/0000016732-13-000023.txt and ticker CPB
# Successfully parsed for file data/10k_raw/AIR/0001047469-13-007797.txt and ticker AIR
# Successfully parsed for file data/10k_raw/CRS/0001104659-13-065850.txt and ticker CRS
# Successfully parsed for file data/10k_raw/ACET/0001188112-13-002611.txt and ticker ACET
# ❌ Only 1 sections found for file
# Successfully parsed for file data/10k_raw/CLX/0001206774-13-003034.txt and ticker CLX
# Successfully parsed for file data/10k_raw/CAG/0001445305-13-001653.txt and ticker CAG
# Successfully parsed for file data/10k_raw/DCI/0000897101-13-001411.txt and ticker DCI
# Successfully parsed for file data/10k_raw/SXI/0000310354-13-000023.txt and ticker SXI
# Successfully parsed for file data/10k_raw/KLAC/0000319201-13-000033.txt and ticker KLAC
# Successfully parsed for file data/10k_raw/NKE/0000320187-13-000092.txt and ticker NKE
# Successfully parsed for file data/10k_raw/WMS/0001193125-13-351333.txt and ticker WMS
# Successfully parsed for file data/10k_raw/GIS/0001193125-13-282371.txt and ticker GIS
# Successfully parsed for file data/10k_raw/KMT/0000055242-13-000017.txt and ticker KMT
# Successfully parsed for file data/10k_raw/LANC/0001193125-13-352262.txt and ticker LANC
# ❌ Only 1 sections found for file
# Successfully parsed for file data/10k_raw/MCS/0001144204-13-045159.txt and ticker MCS
# Successfully parsed for file data/10k_raw/DY/0000067215-13-000046.txt and ticker DY
# Successfully parsed for file data/10k_raw/NSSC/0001157523-13-004445.txt and ticker NSSC
# Successfully parsed for file data/10k_raw/FIZZ/0001437749-13-008687.txt and ticker FIZZ
# Successfully parsed for file data/10k_raw/EAT/0000703351-13-000009.txt and ticker EAT
# Successfully parsed for file data/10k_raw/LRCX/0001193125-13-348269.txt and ticker LRCX
# Successfully parsed for file data/10k_raw/NEOG/0001193125-13-309676.txt and ticker NEOG
# Successfully parsed for file data/10k_raw/AMSWA/0001193125-13-289120.txt and ticker AMSWA
# Successfully parsed for file data/10k_raw/CAH/0000721371-13-000154.txt and ticker CAH
# Successfully parsed for file data/10k_raw/CTAS/0000723254-13-000011.txt and ticker CTAS
# Successfully parsed for file data/10k_raw/PAYX/0000723531-13-000021.txt and ticker PAYX
# Successfully parsed for file data/10k_raw/THO/0001193125-13-380045.txt and ticker THO
# Successfully parsed for file data/10k_raw/DV/0001144204-13-048520.txt and ticker DV
# Successfully parsed for file data/10k_raw/BRC/0000746598-13-000223.txt and ticker BRC
# Successfully parsed for file data/10k_raw/PLL/0000075829-13-000007.txt and ticker PLL
# Successfully parsed for file data/10k_raw/PH/0000076334-13-000157.txt and ticker PH
# Successfully parsed for file data/10k_raw/JKHY/0000779152-13-000028.txt and ticker JKHY
# Successfully parsed for file data/10k_raw/MSFT/0001193125-13-310206.txt and ticker MSFT
# Successfully parsed for file data/10k_raw/PG/0000080424-13-000063.txt and ticker PG
# Successfully parsed for file data/10k_raw/MTN/0000812011-13-000029.txt and ticker MTN
# Successfully parsed for file data/10k_raw/SYNA/0001193125-13-339377.txt and ticker SYNA
# Successfully parsed for file data/10k_raw/PRGO/0000820096-13-000011.txt and ticker PRGO
# Successfully parsed for file data/10k_raw/TECH/0001193125-13-351961.txt and ticker TECH
# Successfully parsed for file data/10k_raw/RGLD/0001047469-13-008238.txt and ticker RGLD
# Successfully parsed for file data/10k_raw/IMGN/0001047469-13-008741.txt and ticker IMGN
# Successfully parsed for file data/10k_raw/CSCO/0000858877-13-000049.txt and ticker CSCO
# Successfully parsed for file data/10k_raw/SCHL/0000930413-13-003986.txt and ticker SCHL
# Successfully parsed for file data/10k_raw/ADP/0000008670-13-000015.txt and ticker ADP
